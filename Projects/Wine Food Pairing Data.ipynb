# %%
import os
import pandas as pd
import numpy as np
import string
# from operator import itemgetter
from collections import Counter, OrderedDict

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
import nltk
nltk.download('punkt')
nltk.download('stopwords')

from gensim.models.phrases import Phrases, Phraser
from gensim.models import Word2Vec

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/wolfepickett/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/wolfepickett/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# First, import the wine dataset.

# %%
base_location = r"../data/wine-reviews"

i = 0
for file in os.listdir(base_location):
    file_location = base_location + '/' + str(file)
    if i==0:
        wine_dataframe = pd.read_csv(file_location, encoding='latin-1')
        i+=1
    else:
        df_to_append = pd.read_csv(file_location, encoding='latin-1', low_memory=False)
        wine_dataframe = pd.concat([wine_dataframe, df_to_append], axis=0)

wine_dataframe.drop_duplicates(subset=['Name'], inplace=True)

geographies = ['Subregion', 'Region', 'Province', 'Country']

for geo in geographies:
    wine_dataframe[geo] = wine_dataframe[geo].apply(lambda x : str(x).strip())

print(wine_dataframe.shape)
# Out:
# (143754, 23)

# %% [markdown]
# Then, the food dataset.

# %%
food_review_dataset = pd.read_csv('../data/food-reviews.csv')
print(food_review_dataset.shape)
# Out:
# (568454, 10)

# %% [markdown]
# ### 1. Training our Word Embeddings
#
# First, we need to train a Word2Vec model on all the words in our corpus. We will process our wine and food terms separately - some of the wine terms will be standardized to account for commonalities in the colorful language of the world of wine.

# %%
wine_reviews_list = list(wine_dataframe['Description'])
food_reviews_list = list(food_review_dataset['Text'])

# %% [markdown]
# To begin, we need to tokenize the terms in our corpus (wine and food).

# %%
full_wine_reviews_list = [str(r) for r in wine_reviews_list]
full_wine_corpus = ' '.join(full_wine_reviews_list)
wine_sentences_tokenized = sent_tokenize(full_wine_corpus)

print(wine_sentences_tokenized[:2])
# Out:
# ['Owned by the Beaune negociant firm Louis Jadot, this producer is major among the Beaujolais crus.', 'As in this wine, the style is rich, wood aged and intense with ripe cherry and acidity.']

# %%
full_food_reviews_list = [str(r) for r in food_reviews_list]
full_food_corpus = ' '.join(full_food_reviews_list)
food_sentences_tokenized = sent_tokenize(full_food_corpus)

print(food_sentences_tokenized[:2])
# Out:
# ['I have bought several of the Vitality canned dog food products and have found them all to be of good quality.', 'The product looks more like a stew than a processed meat and it smells better.']

# %% [markdown]
# Next, the text in each sentence is normalized (tokenize, remove punctuation and remove stopwords).

# %%
# stop_words = set(stopwords.words('english')) 

# punctuation_table = str.maketrans({key: None for key in string.punctuation})
# sno = SnowballStemmer('english')

# def normalize_text(raw_text):
#     try:
#         word_list = word_tokenize(raw_text)
#         normalized_sentence = []
#         for w in word_list:
#             try:
#                 w = str(w)
#                 lower_case_word = str.lower(w)
#                 stemmed_word = sno.stem(lower_case_word)
#                 no_punctuation = stemmed_word.translate(punctuation_table)
#                 if len(no_punctuation) > 1 and no_punctuation not in stop_words:
#                     normalized_sentence.append(no_punctuation)
#             except:
#                 continue
#         return normalized_sentence
#     except:
#         return ''

# normalized_wine_sentences = []
# for s in wine_sentences_tokenized:
#     normalized_text = normalize_text(s)
#     normalized_wine_sentences.append(normalized_text)

# normalized_food_sentences = []
# for s in food_sentences_tokenized:
#     normalized_text = normalize_text(s)
#     normalized_food_sentences.append(normalized_text)

# %%
# from nltk.stem import WordNetLemmatizer

# stop_words = set(stopwords.words('english'))
# punctuation_table = str.maketrans({key: None for key in string.punctuation})
# lemmatizer = WordNetLemmatizer()

# def normalize_text(raw_text):
#     try:
#         word_list = word_tokenize(raw_text)
#         normalized_sentence = [
#             lemmatizer.lemmatize(str.lower(w)).translate(punctuation_table)
#             for w in word_list
#             if len(w) > 1 and w.lower() not in stop_words
#         ]
#         return normalized_sentence
#     except:
#         return []

# normalized_wine_sentences = [
#     normalize_text(s) for s in wine_sentences_tokenized
# ]

# normalized_food_sentences = [
#     normalize_text(s) for s in food_sentences_tokenized
# ]

# %% [markdown]
# Not all of the terms we are interested in are single words. Some of the terms are phrases, consisting of two (or more!) words. An example of this might be 'high tannin'. We can use gensim's Phrases feature to extract all the most relevant bi- and tri-grams from our corpus.
#
# We will train a separate trigram model for wine and for food.

# %%
# first, take care of the wine trigrams
#wine_bigram_model = Phrases(normalized_wine_sentences, min_count=100)
#wine_bigrams = [wine_bigram_model[line] for line in normalized_wine_sentences]
#wine_trigram_model = Phrases(wine_bigrams, min_count=50)
#phrased_wine_sentences = [wine_trigram_model[line] for line in wine_bigrams]
#wine_trigram_model.save('wine_trigrams.pkl')

### now, do the same for food
#food_bigram_model = Phrases(normalized_food_sentences, min_count=100)
#food_bigrams = [food_bigram_model[sent] for sent in normalized_food_sentences]
#food_trigram_model = Phrases(food_bigrams, min_count=50)
#phrased_food_sentences = [food_trigram_model[sent] for sent in food_bigrams]
#food_trigram_model.save('food_trigrams.pkl')

# %% [markdown]
# If the trigram model has already been trained, simply retrieve it.

# %%
wine_trigram_model = Phraser.load('wine_trigrams.pkl')
food_trigram_model = Phraser.load('food_trigrams.pkl')

# %% [markdown]
# Now for the most important part: leveraging existing wine theory, the work of others like Bernard Chen, wine descriptor mappings and the UC Davis wine wheel, the top 5000 most frequent wine terms were reviewed to (i) determine whether they are a descriptor that can be derived by blind tasting, and (ii) whether they are informative (judgments like 'tasty' and 'great' are not considered to be informative). The roughly 1000 descriptors that remain were then mapped onto a normalized descriptor, a category and a class:

# %%
# import spacy

# # Load spaCy model
# nlp = spacy.load('en_core_web_sm')

# def normalize_with_spacy(word):
#     doc = nlp(word)
#     normalized_word = ' '.join([token.lemma_ for token in doc])
#     return normalized_word

# %%
descriptor_mapping = pd.read_csv('descriptor_mapping.csv', encoding='latin1').set_index('raw descriptor')

def return_mapped_descriptor(word, mapping):
    if word in list(mapping.index):
        normalized_word = mapping.at[word, 'level_3']
        return normalized_word
    else:
        #i added this "salt" exception in because there's something weird going on with salt
        # there's a number of words like "salt and pepper" or "seasalt" that aren't getting picked up
        if "salt" in word:
            return "salt"
        return word

normalized_wine_sentences = []
for sent in phrased_wine_sentences:
    normalized_wine_sentence = []
    for word in sent:
        normalized_word = return_mapped_descriptor(word, descriptor_mapping)
        normalized_wine_sentence.append(str(normalized_word))
    normalized_wine_sentences.append(normalized_wine_sentence)

# %% [markdown]
# We will go through the same process for food, but without normalizing the nonaroma descriptors.

# %%
aroma_descriptor_mapping = descriptor_mapping.loc[descriptor_mapping['type'] == 'aroma']
normalized_food_sentences = []
for sent in phrased_food_sentences:
    normalized_food_sentence = []
    for word in sent:
        normalized_word = return_mapped_descriptor(word, aroma_descriptor_mapping)
        normalized_food_sentence.append(str(normalized_word))
    normalized_food_sentences.append(normalized_food_sentence)

# %% [markdown]
# Now, let's combine the wine dataset with our food dataset so we can train our embeddings. We want to make sure that the food and wine embeddings are calculated in the same feature space so that we can compute similarity vectors later on.

# %%
normalized_sentences = normalized_wine_sentences + normalized_food_sentences

# %% [markdown]
# We are ready to train our Word2Vec model!

# %%
wine_word2vec_model = Word2Vec(normalized_sentences, size=300, min_count=8, iter=15)
print(wine_word2vec_model)

wine_word2vec_model.save('food_word2vec_model.bin')
# Out:
# Word2Vec(vocab=37286, size=300, alpha=0.025)

# %%
# if the word2vec model has already been trained, simply load it
wine_word2vec_model = Word2Vec.load("food_word2vec_model.bin")

# %% [markdown]
# ### 2. Preprocessing our Wine Dataset
#
# We can now turn our attention to our wine dataset. Descriptions for a single wine are unlikely to contain sufficient information about all the nonaromas and aromas to yield consistent and reliable pairing recommendations. As such, we will produce recommendations at the grape variety & subregion level.
#
# First, let's normalize the names of the grape varieties in our dataset.

# %%
variety_mapping = {'Shiraz': 'Syrah', 'Pinot Gris': 'Pinot Grigio', 'Pinot Grigio/Gris': 'Pinot Grigio', 
                   'Garnacha, Grenache': 'Grenache', 'Garnacha': 'Grenache', 'CarmenÃ¨re': 'Carmenere',
                    'GrÃ¼ner Veltliner': 'Gruner Veltliner', 'TorrontÃ©s': 'Torrontes', 
                   'RhÃ´ne-style Red Blend': 'Rhone-style Red Blend', 'AlbariÃ±o': 'Albarino',
                  'GewÃ¼rztraminer': 'Gewurztraminer', 'RhÃ´ne-style White Blend': 'Rhone-style White Blend',
                  'SpÃƒÂ¤tburgunder, Pinot Noir': 'Pinot Noir', 'Sauvignon, Sauvignon Blanc': 'Sauvignon Blanc',
                  'Pinot Nero, Pinot Noir': 'Pinot Noir', 'Malbec-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                  'Meritage, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Garnacha, Grenache': 'Grenache',
                   'FumÃ© Blanc': 'Sauvignon Blanc', 'Cabernet Sauvignon-Cabernet Franc, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Cabernet Sauvignon-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Blend, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Malbec-Cabernet Sauvignon, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Merlot-Cabernet Franc, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Merlot-Cabernet Sauvignon, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet Franc-Merlot, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Merlot-Malbec, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend',
                   'Cabernet, Bordeaux-style Red Blend': 'Bordeaux-style Red Blend', 'Primitivo, Zinfandel': 'Zinfandel',
                   'AragonÃªs, Tempranillo': 'Aragonez, Tempranillo'
                  }

def consolidate_varieties(variety_name):
    if variety_name in variety_mapping:
        return variety_mapping[variety_name]
    else:
        return variety_name

wine_df_clean = wine_dataframe.copy()
wine_df_clean['Variety'] = wine_df_clean['Variety'].apply(consolidate_varieties)

# %% [markdown]
# Next, we need to define the set of geography subregions we will use to define our wines. Not too general, not too specific... just right.

# %%
order_of_geographies = ['Subregion', 'Region', 'Province', 'Country']

# replace any nan values in the geography columns with the word none
def replace_nan_for_zero(value):
    if str(value) == '0' or str(value) == 'nan':
        return 'none'
    else:
        return value

for o in order_of_geographies:
    wine_df_clean[o] = wine_df_clean[o].apply(replace_nan_for_zero)

wine_df_clean.loc[:, order_of_geographies].fillna('none', inplace=True)

# %%
variety_geo = wine_df_clean.groupby(['Variety', 'Country', 'Province', 'Region', 'Subregion']).size().reset_index().rename(columns={0:'count'})
variety_geo_sliced = variety_geo.loc[variety_geo['count'] > 1]

vgeos_df = pd.DataFrame(variety_geo_sliced, columns=['Variety', 'Country', 'Province', 'Region', 'Subregion', 'count']) 
vgeos_df.to_csv('varieties_all_geos.csv')

# %%
variety_geo_df = pd.read_csv('varieties_all_geos_normalized.csv', index_col=0)

wine_df_merged = pd.merge(left=wine_df_clean, right=variety_geo_df, left_on=['Variety', 'Country', 'Province', 'Region', 'Subregion'],
                         right_on=['Variety', 'Country', 'Province', 'Region', 'Subregion'])
wine_df_merged.drop(['Unnamed: 0', 'Appellation', 'Bottle Size', 'Category', 'Country', 
                     'Date Published', 'Designation', 'Importer', 'Province', 'Rating', 
                     'Region', 'Reviewer', 'Reviewer Twitter Handle', 'Subregion', 'User Avg Rating', 'Winery', 'count'], 
                    axis=1, inplace=True)
wine_df_merged.shape
# Out:
# (140613, 8)

# %% [markdown]
# We only want to keep wine types (location + variety) that appear frequently enough in our dataset.

# %%
variety_geos = wine_df_merged.groupby(['Variety', 'geo_normalized']).size()
at_least_n_types = variety_geos[variety_geos > 30].reset_index()
wine_df_merged_filtered = pd.merge(wine_df_merged, at_least_n_types, left_on=['Variety', 'geo_normalized'], right_on=['Variety', 'geo_normalized'])
wine_df_merged_filtered = wine_df_merged_filtered[['Name', 'Variety', 'geo_normalized', 'Description']]
print(wine_df_merged_filtered.shape)
# Out:
# (119513, 4)

# %% [markdown]
# Now, we will extract 7 vectors for every wine:
#
# - aroma vector (the aggregate of all the aroma descriptors in a wine)
# - nonaroma vectors (an aggregate vector for only aroma & non-aroma descriptors matching the core tastes below):
#     - sweetness
#     - acid
#     - salt
#     - piquant
#     - fat
#     - bitter
#
#  In our descriptor file, we have defined which normalized descriptors pertain to each nonaroma.

# %%
descriptor_mappings['salt']
# Out:
#                level_3   level_2   level_1   type primary taste  combined
# raw descriptor
# brine            brine  salinity  salinity  aroma          salt  salinity
# brini            brine  salinity  salinity  aroma          salt  salinity
# iodin           iodine  salinity  salinity  aroma          salt  salinity
# ocean            ocean  salinity  salinity  aroma          salt  salinity
# salin           saline  salinity  salinity  aroma          salt  salinity
# sea_salt        saline  salinity  salinity  aroma          salt  salinity
# salt              salt  salinity  salinity  aroma          salt  salinity
# salti             salt  salinity  salinity  aroma          salt  salinity

# %%
descriptor_mapping[descriptor_mapping['primary taste'].fillna('fill').str.contains('salt')]
# Out:
#                level_3   level_2   level_1   type primary taste  combined
# raw descriptor
# brine            brine  salinity  salinity  aroma          salt  salinity
# brini            brine  salinity  salinity  aroma          salt  salinity
# iodin           iodine  salinity  salinity  aroma          salt  salinity
# ocean            ocean  salinity  salinity  aroma          salt  salinity
# salin           saline  salinity  salinity  aroma          salt  salinity
# sea_salt        saline  salinity  salinity  aroma          salt  salinity
# salt              salt  salinity  salinity  aroma          salt  salinity
# salti             salt  salinity  salinity  aroma          salt  salinity

# %%
descriptor_mapping_filtered
# Out:
#                                  level_3        level_2 level_1      type  \
# raw descriptor
# abras                           abrasive    high_tannin  tannin  nonaroma
# angular                          angular    high_tannin  tannin  nonaroma
# astring                       astringent    high_tannin  tannin  nonaroma
# auster                           austere    high_tannin  tannin  nonaroma
# beefi                              beefy    high_tannin  tannin  nonaroma
# bigbon                         big-boned    high_tannin  tannin  nonaroma
# bitter                            bitter    high_tannin  tannin  nonaroma
# bittersweet                  bittersweet    high_tannin  tannin  nonaroma
# brawni                            brawny    high_tannin  tannin  nonaroma
# bulki                              bulky    high_tannin  tannin  nonaroma
# choppi                            choppy    high_tannin  tannin  nonaroma
# classi                            classy     low_tannin  tannin  nonaroma
# compact                           closed    high_tannin  tannin  nonaroma
# closegrain_tannin   close-grained_tannin     low_tannin  tannin  nonaroma
# coars                             coarse    high_tannin  tannin  nonaroma
# alongsid_finegrain    finegrained_tannin     low_tannin  tannin  nonaroma
# finegrain             finegrained_tannin     low_tannin  tannin  nonaroma
# finegrain_tannin      finegrained_tannin     low_tannin  tannin  nonaroma
# firm                                firm    high_tannin  tannin  nonaroma
# fleet_tannin             fleeting_tannin     low_tannin  tannin  nonaroma
# fleshi                            fleshy    high_tannin  tannin  nonaroma
# grabbi                            grabby    high_tannin  tannin  nonaroma
# graini                            grainy    high_tannin  tannin  nonaroma
# graini_tannin                     grainy    high_tannin  tannin  nonaroma
# grip                            gripping    high_tannin  tannin  nonaroma
# tannic_grip              gripping_tannin    high_tannin  tannin  nonaroma
# grippi                            grippy    high_tannin  tannin  nonaroma
# grit                              gritty    high_tannin  tannin  nonaroma
# gritti                            gritty    high_tannin  tannin  nonaroma
# hard                                hard    high_tannin  tannin  nonaroma
# sizabl_tannin                high_tannin    high_tannin  tannin  nonaroma
# tannic_bite                  high_tannin    high_tannin  tannin  nonaroma
# tannic_backbon               high_tannin    high_tannin  tannin  nonaroma
# jag                               jagged    high_tannin  tannin  nonaroma
# masculin                       masculine    high_tannin  tannin  nonaroma
# meati                              meaty    high_tannin  tannin  nonaroma
# moder_tannic               medium_tannin  medium_tannin  tannin  nonaroma
# mild_bitter              mild_bitterness  medium_tannin  tannin  nonaroma
# muscular                        muscular    high_tannin  tannin  nonaroma
# phenol                          phenolic    high_tannin  tannin  nonaroma
# pillowi                          pillowy     low_tannin  tannin  nonaroma
# pleasant_bitter          pleasant_bitter  medium_tannin  tannin  nonaroma
# plush                              plush     low_tannin  tannin  nonaroma
# alongsid_polish                 polished     low_tannin  tannin  nonaroma
# polish                          polished     low_tannin  tannin  nonaroma
# powderi                          powdery     low_tannin  tannin  nonaroma
# raspi                              raspy    high_tannin  tannin  nonaroma
# rough                              rough    high_tannin  tannin  nonaroma
# rough_edg                          rough    high_tannin  tannin  nonaroma
# rustic                            rustic    high_tannin  tannin  nonaroma
# satini                            satiny     low_tannin  tannin  nonaroma
# scratchi                        scratchy     low_tannin  tannin  nonaroma
# silken                             silky     low_tannin  tannin  nonaroma
# silki                              silky     low_tannin  tannin  nonaroma
# sinewi                            sinewy    high_tannin  tannin  nonaroma
# sleek                              sleek     low_tannin  tannin  nonaroma
# smooth                            smooth     low_tannin  tannin  nonaroma
# soft                                soft     low_tannin  tannin  nonaroma
# softer                              soft     low_tannin  tannin  nonaroma
# suppl                             supple     low_tannin  tannin  nonaroma
# tannic                            tannin    high_tannin  tannin  nonaroma
# tight                              tight    high_tannin  tannin  nonaroma
# tight_knit                         tight    high_tannin  tannin  nonaroma
# tight_wound                        tight    high_tannin  tannin  nonaroma
# tighter                            tight    high_tannin  tannin  nonaroma
# alongsid_velveti                 velvety     low_tannin  tannin  nonaroma
# velvet                           velvety     low_tannin  tannin  nonaroma
# velveti                          velvety     low_tannin  tannin  nonaroma
# velveti_textur                   velvety     low_tannin  tannin  nonaroma
# velveti_tannin            velvety_tannin     low_tannin  tannin  nonaroma
#
#                    primary taste       combined
# raw descriptor
# abras                     bitter    high_tannin
# angular                   bitter    high_tannin
# astring                   bitter    high_tannin
# auster                    bitter    high_tannin
# beefi                     bitter    high_tannin
# bigbon                    bitter    high_tannin
# bitter                    bitter    high_tannin
# bittersweet               bitter    high_tannin
# brawni                    bitter    high_tannin
# bulki                     bitter    high_tannin
# choppi                    bitter    high_tannin
# classi                    bitter     low_tannin
# compact                   bitter    high_tannin
# closegrain_tannin         bitter     low_tannin
# coars                     bitter    high_tannin
# alongsid_finegrain        bitter     low_tannin
# finegrain                 bitter     low_tannin
# finegrain_tannin          bitter     low_tannin
# firm                      bitter    high_tannin
# fleet_tannin              bitter     low_tannin
# fleshi                    bitter    high_tannin
# grabbi                    bitter    high_tannin
# graini                    bitter    high_tannin
# graini_tannin             bitter    high_tannin
# grip                      bitter    high_tannin
# tannic_grip               bitter    high_tannin
# grippi                    bitter    high_tannin
# grit                      bitter    high_tannin
# gritti                    bitter    high_tannin
# hard                      bitter    high_tannin
# sizabl_tannin             bitter    high_tannin
# tannic_bite               bitter    high_tannin
# tannic_backbon            bitter    high_tannin
# jag                       bitter    high_tannin
# masculin                  bitter    high_tannin
# meati                     bitter    high_tannin
# moder_tannic              bitter  medium_tannin
# mild_bitter               bitter  medium_tannin
# muscular                  bitter    high_tannin
# phenol                    bitter    high_tannin
# pillowi                   bitter     low_tannin
# pleasant_bitter           bitter  medium_tannin
# plush                     bitter     low_tannin
# alongsid_polish           bitter     low_tannin
# polish                    bitter     low_tannin
# powderi                   bitter     low_tannin
# raspi                     bitter    high_tannin
# rough                     bitter    high_tannin
# rough_edg                 bitter    high_tannin
# rustic                    bitter    high_tannin
# satini                    bitter     low_tannin
# scratchi                  bitter     low_tannin
# silken                    bitter     low_tannin
# silki                     bitter     low_tannin
# sinewi                    bitter    high_tannin
# sleek                     bitter     low_tannin
# smooth                    bitter     low_tannin
# soft                      bitter     low_tannin
# softer                    bitter     low_tannin
# suppl                     bitter     low_tannin
# tannic                    bitter    high_tannin
# tight                     bitter    high_tannin
# tight_knit                bitter    high_tannin
# tight_wound               bitter    high_tannin
# tighter                   bitter    high_tannin
# alongsid_velveti          bitter     low_tannin
# velvet                    bitter     low_tannin
# velveti                   bitter     low_tannin
# velveti_textur            bitter     low_tannin
# velveti_tannin            bitter     low_tannin

# %%
wine_reviews = list(wine_df_merged_filtered['Description'])

descriptor_mapping = pd.read_csv('descriptor_mapping_tastes.csv', encoding='latin1').set_index('raw descriptor')

core_tastes = ['aroma', 'weight', 'sweet', 'acid', 'salt', 'piquant', 'fat', 'bitter']
descriptor_mappings = dict()
for c in core_tastes:
    if c=='aroma':
        descriptor_mapping_filtered=descriptor_mapping.loc[descriptor_mapping['type']=='aroma']
    else:
        descriptor_mapping_filtered=descriptor_mapping.loc[descriptor_mapping['primary taste']==c]
    descriptor_mappings[c] = descriptor_mapping_filtered                                                   
    

def return_descriptor_from_mapping(descriptor_mapping, word, core_taste):
    if word in list(descriptor_mapping.index):
        descriptor_to_return = descriptor_mapping['combined'][word]
        return descriptor_to_return
    else:
        return None

review_descriptors = []
for review in wine_reviews:
    taste_descriptors = []
    normalized_review = normalize_text(review)
    phrased_review = wine_trigram_model[normalized_review]
#     print(phrased_review)
    
    for c in core_tastes:                                                      
        descriptors_only = [return_descriptor_from_mapping(descriptor_mappings[c], word, c) for word in phrased_review]
        no_nones = [str(d).strip() for d in descriptors_only if d is not None]
        descriptorized_review = ' '.join(no_nones)
        taste_descriptors.append(descriptorized_review)
    review_descriptors.append(taste_descriptors)

# %%
descriptor_mapping[descriptor_mapping.apply(lambda row: row.astype(str).str.contains('salinity').any(), axis=1) ==True]
# Out:
#                level_3   level_2   level_1   type primary taste  combined
# raw descriptor
# brine            brine  salinity  salinity  aroma          salt  salinity
# brini            brine  salinity  salinity  aroma          salt  salinity
# iodin           iodine  salinity  salinity  aroma          salt  salinity
# ocean            ocean  salinity  salinity  aroma          salt  salinity
# salin           saline  salinity  salinity  aroma          salt  salinity
# sea_salt        saline  salinity  salinity  aroma          salt  salinity
# salt              salt  salinity  salinity  aroma          salt  salinity
# salti             salt  salinity  salinity  aroma          salt  salinity

# %%
descriptor_mapping[descriptor_mapping['combined'].str.contains('salinity')]
# Out:
#                level_3   level_2   level_1   type primary taste  combined
# raw descriptor
# brine            brine  salinity  salinity  aroma          salt  salinity
# brini            brine  salinity  salinity  aroma          salt  salinity
# iodin           iodine  salinity  salinity  aroma          salt  salinity
# ocean            ocean  salinity  salinity  aroma          salt  salinity
# salin           saline  salinity  salinity  aroma          salt  salinity
# sea_salt        saline  salinity  salinity  aroma          salt  salinity
# salt              salt  salinity  salinity  aroma          salt  salinity
# salti             salt  salinity  salinity  aroma          salt  salinity

# %%
descriptor_mapping
# Out:
#                     level_3       level_2 level_1      type primary taste  \
# raw descriptor
# abras              abrasive   high_tannin  tannin  nonaroma        bitter
# acacia               acacia       flowery  flower     aroma           NaN
# acacia_flower        acacia       flowery  flower     aroma           NaN
# aciddriven      acid_driven     high_acid    acid  nonaroma          acid
# aggress          aggressive     high_acid    acid  nonaroma          acid
# ...                     ...           ...     ...       ...           ...
# zest                   zest  citrus_fruit   fruit     aroma           NaN
# zesti                 zesty     high_acid    acid  nonaroma          acid
# zing                  zingy     high_acid    acid  nonaroma          acid
# zingi                 zingy     high_acid    acid  nonaroma          acid
# zippi                 zippy     high_acid    acid  nonaroma          acid
#
#                    combined
# raw descriptor
# abras           high_tannin
# acacia               acacia
# acacia_flower        acacia
# aciddriven        high_acid
# aggress           high_acid
# ...                     ...
# zest                   zest
# zesti             high_acid
# zing              high_acid
# zingi             high_acid
# zippi             high_acid
#
# [1014 rows x 6 columns]

# %% [markdown]
# Now we will take the list of descriptors for each wine and its aroma/nonaroma vectors and compute a TF-IDF weighted embedding for each. We will store the results in a dataframe.

# %%
print(review_vecs_df.shape)
review_vecs_df.isnull().sum()
# Out:
# (119513, 8)
# aroma        1139
# weight      58896
# sweet       92570
# acid        66406
# salt       119513
# piquant    107755
# fat        112552
# bitter      84517
# dtype: int64

# %%
taste_descriptors = []
taste_vectors = []

for n, taste in enumerate(core_tastes):
    print(taste)
    taste_words = [r[n] for r in review_descriptors]
    
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit(taste_words)
    dict_of_tfidf_weightings = dict(zip(X.get_feature_names(), X.idf_))
        
    wine_review_descriptors = []
    wine_review_vectors = []
    
    for d in taste_words:
        descriptor_count = 0
        weighted_review_terms = []
        terms = d.split(' ')
        for term in terms:
            if term in dict_of_tfidf_weightings.keys():
                tfidf_weighting = dict_of_tfidf_weightings[term]
                try:
                    word_vector = wine_word2vec_model.wv.get_vector(term).reshape(1, 300)
                    weighted_word_vector = tfidf_weighting * word_vector
                    weighted_review_terms.append(weighted_word_vector)
                    descriptor_count += 1
                except:
                    continue
            else:
                continue
        try:
            review_vector = sum(weighted_review_terms)/len(weighted_review_terms)
            review_vector = review_vector[0]
        except:
            review_vector = np.nan
#         terms_and_vec = [terms, review_vector]
        wine_review_vectors.append(review_vector)
        wine_review_descriptors.append(terms)
    
    taste_vectors.append(wine_review_vectors)
    taste_descriptors.append(wine_review_descriptors)
    

taste_vectors_t = list(map(list, zip(*taste_vectors)))
taste_descriptors_t = list(map(list, zip(*taste_descriptors)))

review_vecs_df = pd.DataFrame(taste_vectors_t, columns=core_tastes)

columns_taste_descriptors = [a + '_descriptors' for a in core_tastes]
review_descriptors_df = pd.DataFrame(taste_descriptors_t, columns=columns_taste_descriptors)

wine_df_vecs = pd.concat([wine_df_merged_filtered, review_descriptors_df, review_vecs_df], axis=1)
wine_df_vecs.head(5)
# Out:
# aroma
# weight
# sweet
# acid
# salt
# piquant
# fat
# bitter
#                                                 Name Variety  \
# 0  ChÃ¢teau des Jacques 2016 Clos des Thorins  (M...   Gamay
# 1  ChÃ¢teau des Jacques 2016 La Roche  (Moulin-Ã ...   Gamay
# 2  Yohan Lardy 2016 Vieilles Vignes de 1903  (Mou...   Gamay
# 3  Domaine Anita 2017 Reine de Nuit  (Moulin-Ã -V...   Gamay
# 4  Albert Bichot 2016 Domaine de RochegrÃ¨s  (Mou...   Gamay
#
#        geo_normalized                                        Description  \
# 0  Beaujolais, France  Owned by the Beaune negociant firm Louis Jadot...
# 1  Beaujolais, France  This well-structured, layered wine offers beau...
# 2  Beaujolais, France  This amazing wine comes from vines that are mo...
# 3  Beaujolais, France  Night harvesting of grapes for this wine has p...
# 4  Beaujolais, France  From a 12-acre parcel, this wine is ripe, with...
#
#                                aroma_descriptors          weight_descriptors  \
# 0                       [wood_age, ripe, cherry]               [full_bodied]
# 1  [ripe, cherry, red_berry, fruit, wood, spice]               [full_bodied]
# 2                    [fruit, juicy, spice, ripe]               [full_bodied]
# 3                          [fruit, juicy, fruit]                          []
# 4                     [ripe, wood, spice, fruit]  [full_bodied, full_bodied]
#
#   sweet_descriptors        acid_descriptors salt_descriptors  \
# 0                []                      []               []
# 1                []  [high_acid, high_acid]               []
# 2                []                      []               []
# 3                []             [high_acid]               []
# 4                []                      []               []
#
#   piquant_descriptors fat_descriptors bitter_descriptors  \
# 0                  []              []      [high_tannin]
# 1                  []              []                 []
# 2                  []              []                 []
# 3                  []              []                 []
# 4                  []              []                 []
#
#                                                aroma  \
# 0  [1.9602046, 4.73426, -2.9098356, -0.89067596, ...
# 1  [0.7551542, 2.5104544, 1.5750221, 0.45335922, ...
# 2  [0.91680926, 1.7878555, 0.12522465, -0.2668207...
# 3  [0.10998821, 1.6187763, -1.2864422, 1.2346917,...
# 4  [1.0366638, 2.403193, -0.48233217, -0.5852486,...
#
#                                               weight sweet  \
# 0  [1.8466986, -1.0238022, 1.852622, 0.5019164, -...   NaN
# 1  [1.8466986, -1.0238022, 1.852622, 0.5019164, -...   NaN
# 2  [1.8466986, -1.0238022, 1.852622, 0.5019164, -...   NaN
# 3                                                NaN   NaN
# 4  [1.8466986, -1.0238022, 1.852622, 0.5019164, -...   NaN
#
#                                                 acid  salt piquant  fat  \
# 0                                                NaN   NaN     NaN  NaN
# 1  [-1.4836614, 1.5299902, 0.52740586, 1.7276714,...   NaN     NaN  NaN
# 2                                                NaN   NaN     NaN  NaN
# 3  [-1.4836614, 1.5299902, 0.52740586, 1.7276714,...   NaN     NaN  NaN
# 4                                                NaN   NaN     NaN  NaN
#
#                                               bitter
# 0  [0.4430586, -0.26917166, 1.1608604, -1.1486917...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# If we don't have a nonaroma embedding for one of the wines, we will simply take the average nonaroma embedding for all the wines in the dataset.

# %%
# pull the average embedding for the wine attribute across all wines. 
avg_taste_vecs = dict()
for t in core_tastes:
    # look at the average embedding for a taste, across all wines that have descriptors for that taste 
    review_arrays = wine_df_vecs[t].dropna()
    average_taste_vec = np.average(review_arrays)
    avg_taste_vecs[t] = average_taste_vec
# Out:
# /Users/kevincoyle/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /Users/kevincoyle/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# Now, let's find the average embedding for each type of wine (aromas and all nonaromas). We have defined the different types of wines by grape variety and geography, keeping only those with a sufficiently large sample size.
#
# For each variety, we will pull (i) a 300-dimensional aroma vector, and (ii) 7 non-aroma scalars.

# %%
normalized_geos = list(set(zip(wine_df_vecs['Variety'], wine_df_vecs['geo_normalized'])))

def subset_wine_vectors(list_of_varieties, wine_attribute):
    wine_variety_vectors = []
    for v in list_of_varieties:

        one_var_only = wine_df_vecs.loc[(wine_df_vecs['Variety'] == v[0]) & 
                                                (wine_df_vecs['geo_normalized'] == v[1])]
        if len(list(one_var_only.index)) < 1 or str(v[1][-1]) == '0':
            continue
        else:
            taste_vecs = list(one_var_only[wine_attribute])
            taste_vecs = [avg_taste_vecs[wine_attribute] if 'numpy' not in str(type(x)) else x for x in taste_vecs]
            average_variety_vec = np.average(taste_vecs, axis=0)
            
            descriptor_colname = wine_attribute + '_descriptors'
            all_descriptors = [i[0] for i in list(one_var_only[descriptor_colname])]
            word_freqs = Counter(all_descriptors)
            most_common_words = word_freqs.most_common(50)
            top_n_words = [(i[0], "{:.2f}".format(i[1]/len(taste_vecs))) for i in most_common_words]
            top_n_words = [i for i in top_n_words if len(i[0])>2]
            wine_variety_vector = [v, average_variety_vec, top_n_words]
                
            wine_variety_vectors.append(wine_variety_vector)
            
    return wine_variety_vectors


def pca_wine_variety(list_of_varieties, wine_attribute, pca=True):
    wine_var_vectors = subset_wine_vectors(normalized_geos, wine_attribute)
    
    wine_varieties = [str(w[0]).replace('(', '').replace(')', '').replace("'", '').replace('"', '') for w in wine_var_vectors]
    wine_var_vec = [w[1] for w in wine_var_vectors]
    print("wine var vec shape", np.array(wine_var_vec).shape)
    if pca:
        pca = PCA(1)
        #i was getting errors about shape, so we just run a check to make sure we've got a 2d array
        if len(np.array(wine_var_vec).shape) >1:
            wine_var_vec = pca.fit_transform(wine_var_vec) 
        else:
            pass
        wine_var_vec = pd.DataFrame(wine_var_vec, index=wine_varieties)
    else:
        wine_var_vec = pd.Series(wine_var_vec, index=wine_varieties)
    wine_var_vec.sort_index(inplace=True)
    
    wine_descriptors = pd.DataFrame([w[2] for w in wine_var_vectors], index=wine_varieties)
    wine_descriptors = pd.melt(wine_descriptors.reset_index(), id_vars='index')
    wine_descriptors.sort_index(inplace=True)
    
    return wine_var_vec, wine_descriptors

taste_dataframes = []
# generate the dataframe of aromas vectors as output, 
aroma_vec, aroma_descriptors = pca_wine_variety(normalized_geos, 'aroma', pca=False)
taste_dataframes.append(aroma_vec)

# generate the dataframes of nonaroma scalars
for tw in core_tastes[1:]:
    print("the taste is", tw)
    pca_w_dataframe, nonaroma_descriptors = pca_wine_variety(normalized_geos, tw, pca=True)
    taste_dataframes.append(pca_w_dataframe)
    
# combine all the dataframes created above into one 
all_nonaromas = pd.concat(taste_dataframes, axis=1)
all_nonaromas.columns = core_tastes
# Out:
# wine var vec shape (482, 300)
# the taste is weight
# wine var vec shape (482, 300)
# the taste is sweet
# wine var vec shape (482, 300)
# the taste is acid
# wine var vec shape (482, 300)
# the taste is salt
# wine var vec shape (482,)
# the taste is piquant
# wine var vec shape (482, 300)
# the taste is fat
# wine var vec shape (482, 300)
# the taste is bitter
# wine var vec shape (482, 300)

# %%
core_tastes
# Out:
# ['aroma', 'weight', 'sweet', 'acid', 'salt', 'piquant', 'fat', 'bitter']

# %%
all_nonaromas.isnull().sum()
# Out:
# aroma        0
# weight       0
# sweet        0
# acid         0
# salt       482
# piquant      0
# fat          0
# bitter       0
# dtype: int64

# %%
pd.DataFrame(pca_w_dataframe)
# Out:
#                                                            0
# Aglianico, Italian Red, Basilicata, Southern It...  0.001260
# Aglianico, Italian Red, Campania, Southern Ital...  0.000775
# Alsace white blend, White Blend, Alsace, France    -0.000404
# Arneis, Italian White, Piedmont, Northwest Ital... -0.000658
# Austrian Red Blend, Red Blends, Burgenland, Aus...  0.000432
# Austrian white blend, White Blend, Burgenland, ... -0.000892
# Austrian white blend, White Blend, Niederosterr... -0.000188
# Bordeaux-style Red Blend, Bourg & Blaye, Bordea...  0.000559
# Bordeaux-style Red Blend, Coastal Region, South...  0.000433
# Bordeaux-style Red Blend, Colchagua Valley, Cen...  0.000387
# Bordeaux-style Red Blend, Columbia Valley, Wash...  0.000315
# Bordeaux-style Red Blend, Entre-Deux-Mers, Bord...  0.000545
# Bordeaux-style Red Blend, Finger Lakes, New Yor... -0.000105
# Bordeaux-style Red Blend, Galilee, Israel          -0.000588
# Bordeaux-style Red Blend, Graves, Bordeaux, France  0.000467
# Bordeaux-style Red Blend, Hawkes Bay, New Zealand   0.000373
# Bordeaux-style Red Blend, Judea, Israel             0.000208
# Bordeaux-style Red Blend, Libournais, Bordeaux,...  0.000300
# Bordeaux-style Red Blend, Long Island, New York...  0.000259
# Bordeaux-style Red Blend, Maipo Valley, Central...  0.000623
# Bordeaux-style Red Blend, Medoc, Bordeaux, France   0.000481
# Bordeaux-style Red Blend, Mendoza, Argentina        0.000767
# Bordeaux-style Red Blend, Napa Valley, North Co...  0.000253
# Bordeaux-style Red Blend, Paso Robles, Central ...  0.000048
# Bordeaux-style Red Blend, San Francisco Bay, Ce...  0.000328
# Bordeaux-style Red Blend, Santa Barbara, Centra... -0.000220
# Bordeaux-style Red Blend, Sauternais, Bordeaux,...  0.000453
# Bordeaux-style Red Blend, Sonoma Valley, North ...  0.000190
# Bordeaux-style Red Blend, South Australia, Aust... -0.000029
# Bordeaux-style Red Blend, Southwest France, France  0.000478
# Bordeaux-style Red Blend, Virginia, USA             0.000350
# Bordeaux-style Red Blend, Western Australia, Au...  0.000109
# Bordeaux-style White Blend, White Blend, Bourg ... -0.000872
# Bordeaux-style White Blend, White Blend, Columb... -0.000776
# Bordeaux-style White Blend, White Blend, Entre-... -0.000737
# Bordeaux-style White Blend, White Blend, Graves... -0.000425
# Bordeaux-style White Blend, White Blend, Sauter... -0.000401
# Bordeaux-style White Blend, White Blend, Southw... -0.000788
# Cabernet Franc, Anjou-Saumar, Loire Valley, France  0.000074
# Cabernet Franc, Columbia Valley, Washington, USA    0.000120
# Cabernet Franc, Finger Lakes, New York, USA        -0.000130
# Cabernet Franc, Long Island, New York, USA          0.000562
# Cabernet Franc, Mendoza, Argentina                  0.001084
# Cabernet Franc, Napa Valley, North Coast, Calif...  0.000560
# Cabernet Franc, San Francisco Bay, Central Coas...  0.000099
# Cabernet Franc, Sierra Foothills, California, USA   0.001165
# Cabernet Franc, Sonoma Valley, North Coast, Cal...  0.000270
# Cabernet Franc, Southern Oregon, Oregon, USA        0.000528
# Cabernet Franc, Touraine, Loire Valley, France      0.000270
# Cabernet Franc, Virginia, USA                      -0.000085
# Cabernet Sauvignon, Aconcagua Valley, Aconcagua...  0.000756
# Cabernet Sauvignon, Cachapoal Valley, Central V...  0.001568
# Cabernet Sauvignon, Catalunya, Northeast Spain,...  0.000919
# Cabernet Sauvignon, Clear Lake, North Coast, Ca...  0.000821
# Cabernet Sauvignon, Coastal Region, South Africa    0.000299
# Cabernet Sauvignon, Colchagua Valley, Central V...  0.001026
# Cabernet Sauvignon, Columbia Valley, Oregon, USA    0.000409
# Cabernet Sauvignon, Columbia Valley, Washington...  0.000657
# Cabernet Sauvignon, Curico Valley, Central Vall...  0.000821
# Cabernet Sauvignon, Finger Lakes, New York, USA     0.000285
# Cabernet Sauvignon, Galilee, Israel                -0.000339
# Cabernet Sauvignon, Inland Valleys, California,...  0.000159
# Cabernet Sauvignon, Judea, Israel                  -0.000526
# Cabernet Sauvignon, Long Island, New York, USA      0.000442
# Cabernet Sauvignon, Maipo Valley, Central Valle...  0.000838
# Cabernet Sauvignon, Maule Valley, Central Valle...  0.000953
# Cabernet Sauvignon, Mendocino, North Coast, Cal...  0.000903
# Cabernet Sauvignon, Mendoza, Argentina              0.001002
# Cabernet Sauvignon, Napa Valley, North Coast, C...  0.000354
# Cabernet Sauvignon, Paso Robles, Central Coast,... -0.000282
# Cabernet Sauvignon, Rapel Valley, Central Valle...  0.001158
# Cabernet Sauvignon, Salta, Argentina                0.000860
# Cabernet Sauvignon, San Francisco Bay, Central ...  0.000428
# Cabernet Sauvignon, Santa Barbara, Central Coas... -0.000281
# Cabernet Sauvignon, Sierra Foothills, Californi...  0.001015
# Cabernet Sauvignon, Sonoma Valley, North Coast,...  0.000248
# Cabernet Sauvignon, South Australia, Australia      0.000349
# Cabernet Sauvignon, South Coast, California, USA   -0.000122
# Cabernet Sauvignon, Southern Oregon, Oregon, USA    0.000947
# Cabernet Sauvignon, Tuscany, Central Italy, Italy   0.000522
# Cabernet Sauvignon, Western Australia, Australia    0.000316
# Cabernet Sauvignon-Malbec, Bordeaux-style Red B...  0.000903
# Cabernet Sauvignon-Syrah, Red Blends, Columbia ...  0.000638
# Cannonau, Grenache, Sardinia, Southern Italy, I... -0.000077
# Chardonnay, Auckland, New Zealand                  -0.000657
# Chardonnay, Beaujolais, France                     -0.000916
# Chardonnay, Breede River Valley                    -0.000781
# Chardonnay, British Columbia, Canada               -0.000313
# Chardonnay, Burgenland, Austria                    -0.000827
# Chardonnay, Cape South Coast, South Africa         -0.000639
# Chardonnay, Casablanca Valley, Aconcagua Region... -0.000392
# Chardonnay, Catalunya, Northeast Spain, Spain      -0.000545
# Chardonnay, Chablis, Burgundy, France              -0.000045
# Chardonnay, Champagne, France                      -0.000033
# Chardonnay, Clear Lake, North Coast, California    -0.000871
# Chardonnay, Coastal Region, South Africa           -0.000935
# Chardonnay, Colchagua Valley, Central Valley, C... -0.000403
# Chardonnay, Columbia Valley, Washington, USA       -0.000594
# Chardonnay, Cote Chalonnaise, Burgundy, France     -0.000363
# Chardonnay, Cote de Beaune, Burgundy, France       -0.000227
# Chardonnay, Cote de Nuits, Burgundy, France        -0.000298
# Chardonnay, Curico Valley, Central Valley, Chile   -0.000628
# Chardonnay, Finger Lakes, New York, USA            -0.000642
# Chardonnay, Friuli-Venezia Giulia, Northeast It... -0.000861
# Chardonnay, Galilee, Israel                        -0.001123
# Chardonnay, Gisborne, New Zealand                  -0.001010
# Chardonnay, Hawkes Bay, New Zealand                -0.000768
# Chardonnay, Inland Valleys, California, USA        -0.001051
# Chardonnay, Jura, Burgundy, France                 -0.000019
# Chardonnay, Limari Valley, Coquimbo Region, Chile  -0.000322
# Chardonnay, Lombardy, Northwest Italy, Italy       -0.000761
# Chardonnay, Long Island, New York, USA             -0.000778
# Chardonnay, Maconnais, Burgundy, France            -0.000485
# Chardonnay, Maipo Valley, Central Valley, Chile    -0.000366
# Chardonnay, Marlborough, New Zealand               -0.000821
# Chardonnay, Maule Valley, Central Valley, Chile    -0.000197
# Chardonnay, Mendocino, North Coast, California,... -0.000683
# Chardonnay, Mendoza, Argentina                     -0.000253
# Chardonnay, Monterey, Central Coast, California... -0.000163
# Chardonnay, Napa Valley, North Coast, Californi... -0.000570
# Chardonnay, Napa-Sonoma, North Coast, Californi... -0.000509
# Chardonnay, Navarra, Northeast Spain, Spain        -0.000486
# Chardonnay, New South Wales, Australia             -0.000968
# Chardonnay, Paso Robles, Central Coast, Califor... -0.000002
# Chardonnay, San Antonio, Aconcagua Region, Chile   -0.000136
# Chardonnay, San Francisco Bay, Central Coast, C... -0.000372
# Chardonnay, San Luis Obispo, Central Coast, Cal... -0.000004
# Chardonnay, Santa Barbara, Central Coast, Calif...  0.000363
# Chardonnay, Sicily, Southern Italy, Italy          -0.000993
# Chardonnay, Sonoma Valley, North Coast, Califor... -0.000513
# Chardonnay, South Australia, Australia             -0.000689
# Chardonnay, Southern Oregon, Oregon, USA           -0.000531
# Chardonnay, Trento, Northeast Italy, Italy         -0.000658
# Chardonnay, Victoria, Australia                    -0.000818
# Chardonnay, Virginia, USA                          -0.000760
# Chardonnay, Western Australia, Australia           -0.000616
# Chardonnay, Willamette Valley, Oregon, USA         -0.000339
# Dolcetto, Italian Red, Piedmont, Northwest Ital... -0.000079
# Durella, Italian White, Veneto, Northeast Italy... -0.000026
# Falanghina, Italian White, Campania, Southern I... -0.000990
# Fiano, Italian White, Campania, Southern Italy,... -0.000643
# Frappato, Italian Red, Sicily, Southern Italy, ... -0.000410
# Friulano, Italian White, Friuli-Venezia Giulia,... -0.000662
# Gamay, Beaujolais, France                           0.000297
# Garganega, Italian White, Veneto, Northeast Ita... -0.000946
# Glera, Italian White, Veneto, Northeast Italy, ... -0.000721
# Greco, Italian White, Campania, Southern Italy,... -0.001063
# Grenache, Aragon, Northeast Spain, Spain            0.000474
# Grenache, Castilla-La Mancha, Central Spain, Spain -0.000053
# Grenache, Catalunya, Northeast Spain, Spain         0.000453
# Grenache, Columbia Valley, Washington, USA         -0.000655
# Grenache, La Rioja, Northeast Spain, Spain          0.000791
# Grenache, Navarra, Northeast Spain, Spain           0.000427
# Grenache, Paso Robles, Central Coast, Californi... -0.000024
# Grenache, Santa Barbara, Central Coast, Califor...  0.000206
# Grenache, Sierra Foothills, California, USA         0.001210
# Grenache, Sonoma Valley, North Coast, Californi...  0.000471
# Grenache, South Australia, Australia               -0.000283
# Grenache, Southern Oregon, Oregon, USA             -0.000096
# Grenache, Southern Rhone, Rhone Valley, France      0.000541
# Grillo, Italian White, Sicily, Southern Italy, ... -0.000853
# Gros and Petit Manseng, White Blend, Southwest ... -0.000795
# Gruner Veltliner, Burgenland, Austria              -0.000762
# Gruner Veltliner, Finger Lakes, New York, USA      -0.000855
# Gruner Veltliner, Niederosterreich, Austria        -0.000552
# Gruner Veltliner, Vienna, Austria                  -0.000571
# Lagrein, Italian Red, Alto Adige, Northeast Ita...  0.000199
# Malbec, Colchagua Valley, Central Valley, Chile     0.001071
# Malbec, Columbia Valley, Washington, USA           -0.000096
# Malbec, Mendoza, Argentina                          0.000666
# Malbec, Napa Valley, North Coast, California, USA   0.000303
# Malbec, Patagonia, Argentina                        0.000597
# Malbec, Salta, Argentina                            0.000703
# Malbec, San Juan, Argentina                         0.000526
# Malbec, Sonoma Valley, North Coast, California,...  0.000852
# Malbec, Southern Oregon, Oregon, USA                0.000168
# Malbec, Southwest France, France                    0.000414
# Merlot, Cachapoal Valley, Central Valley, Chile     0.000265
# Merlot, Coastal Region, South Africa               -0.000252
# Merlot, Colchagua Valley, Central Valley, Chile     0.000661
# Merlot, Columbia Valley, Washington, USA            0.000395
# Merlot, Curico Valley, Central Valley, Chile        0.000510
# Merlot, Finger Lakes, New York, USA                 0.000051
# Merlot, Galilee, Israel                            -0.000703
# Merlot, Hawkes Bay, New Zealand                    -0.000198
# Merlot, Inland Valleys, California, USA            -0.000184
# Merlot, Libournais, Bordeaux, France                0.000099
# Merlot, Long Island, New York, USA                  0.000012
# Merlot, Maipo Valley, Central Valley, Chile         0.000368
# Merlot, Maule Valley, Central Valley, Chile         0.000821
# Merlot, Mendocino, North Coast, California, USA     0.000541
# Merlot, Mendoza, Argentina                          0.000614
# Merlot, Napa Valley, North Coast, California, USA   0.000225
# Merlot, Paso Robles, Central Coast, California,... -0.000121
# Merlot, Rapel Valley, Central Valley, Chile         0.000331
# Merlot, San Francisco Bay, Central Coast, Calif...  0.000135
# Merlot, Santa Barbara, Central Coast, Californi... -0.000374
# Merlot, Sonoma Valley, North Coast, California,...  0.000108
# Merlot, Southern Oregon, Oregon, USA                0.001046
# Merlot, Tuscany, Central Italy, Italy               0.001272
# Montepulciano, Italian Red, Abruzzo, Central It...  0.000228
# Nebbiolo, Lombardy, Northwest Italy, Italy          0.000734
# Nebbiolo, Piedmont, Northwest Italy, Italy          0.001471
# Negroamaro, Italian Red, Puglia, Southern Italy...  0.000533
# Nerello Mascalese, Italian Red, Sicily, Souther...  0.000539
# Nero dAvola, Italian Red, Sicily, Southern Ital...  0.000219
# Petite Sirah, Clear Lake, North Coast, California   0.000632
# Petite Sirah, Columbia Valley, Washington, USA      0.001426
# Petite Sirah, Inland Valleys, California, USA       0.001048
# Petite Sirah, Mendocino, North Coast, Californi...  0.000972
# Petite Sirah, Napa Valley, North Coast, Califor...  0.000216
# Petite Sirah, Paso Robles, Central Coast, Calif... -0.000242
# Petite Sirah, San Francisco Bay, Central Coast,...  0.000804
# Petite Sirah, Sierra Foothills, California, USA     0.001314
# Petite Sirah, Sonoma Valley, North Coast, Calif...  0.000336
# Pinot Grigio, Alsace, France                       -0.000450
# Pinot Grigio, Alto Adige, Northeast Italy, Italy   -0.000975
# Pinot Grigio, Central Otago, New Zealand           -0.000802
# Pinot Grigio, Columbia Valley, Washington, USA     -0.000416
# Pinot Grigio, Finger Lakes, New York, USA          -0.000589
# Pinot Grigio, Friuli-Venezia Giulia, Northeast ... -0.000808
# Pinot Grigio, Marlborough, New Zealand             -0.000696
# Pinot Grigio, Mendocino, North Coast, Californi... -0.000565
# Pinot Grigio, Mendoza, Argentina                    0.000201
# Pinot Grigio, Sonoma Valley, North Coast, Calif... -0.000447
# Pinot Grigio, Southern Oregon, Oregon, USA         -0.000167
# Pinot Grigio, Trento, Northeast Italy, Italy       -0.000824
# Pinot Grigio, Veneto, Northeast Italy, Italy       -0.000942
# Pinot Grigio, Willamette Valley, Oregon, USA       -0.000383
# Pinot Noir, Alsace, France                          0.000111
# Pinot Noir, Alto Adige, Northeast Italy, Italy      0.000160
# Pinot Noir, Bio-Bio Valley, South Region, Chile     0.000129
# Pinot Noir, Burgenland, Austria                     0.000228
# Pinot Noir, Canterbury and Waipara, New Zealand    -0.000054
# Pinot Noir, Cape South Coast, South Africa         -0.000353
# Pinot Noir, Casablanca Valley, Aconcagua Region...  0.000211
# Pinot Noir, Central Otago, New Zealand             -0.000131
# Pinot Noir, Centre, Loire Valley, France            0.000326
# Pinot Noir, Champagne, France                      -0.000120
# Pinot Noir, Columbia Valley, Oregon, USA           -0.000238
# Pinot Noir, Columbia Valley, Washington, USA       -0.000345
# Pinot Noir, Cote Chalonnaise, Burgundy, France      0.000614
# Pinot Noir, Cote de Beaune, Burgundy, France        0.000501
# Pinot Noir, Cote de Nuits, Burgundy, France         0.000535
# Pinot Noir, Finger Lakes, New York, USA             0.000042
# Pinot Noir, Lombardy, Northwest Italy, Italy       -0.000545
# Pinot Noir, Marlborough, New Zealand               -0.000332
# Pinot Noir, Maule Valley, Central Valley, Chile    -0.000267
# Pinot Noir, Mendocino, North Coast, California,...  0.000396
# Pinot Noir, Mendoza, Argentina                     -0.000074
# Pinot Noir, Monterey, Central Coast, California... -0.000408
# Pinot Noir, Napa Valley, North Coast, Californi...  0.000121
# Pinot Noir, Napa-Sonoma, North Coast, Californi...  0.000065
# Pinot Noir, Nelson, New Zealand                     0.000115
# Pinot Noir, Niederosterreich, Austria               0.000459
# Pinot Noir, Patagonia, Argentina                    0.000684
# Pinot Noir, San Antonio, Aconcagua Region, Chile    0.000340
# Pinot Noir, San Benito, Central Coast, Californ...  0.000025
# Pinot Noir, San Francisco Bay, Central Coast, C... -0.000277
# Pinot Noir, San Luis Obispo, Central Coast, Cal... -0.000163
# Pinot Noir, Santa Barbara, Central Coast, Calif... -0.000256
# Pinot Noir, Sonoma Valley, North Coast, Califor... -0.000106
# Pinot Noir, South Australia, Australia             -0.000135
# Pinot Noir, Southern Oregon, Oregon, USA            0.000105
# Pinot Noir, Tasmania, Australia                    -0.000335
# Pinot Noir, Victoria, Australia                    -0.000333
# Pinot Noir, Wairarapa, New Zealand                 -0.000052
# Pinot Noir, Willamette Valley, Oregon, USA          0.000105
# Provence red blend, Red Blends, Provence, France    0.000491
# Red Blends, Red Blends, Alentejo, Portugal         -0.000053
# Red Blends, Red Blends, Aragon, Northeast Spain...  0.000856
# Red Blends, Red Blends, Burgenland, Austria         0.000286
# Red Blends, Red Blends, Cachapoal Valley, Centr...  0.000009
# Red Blends, Red Blends, Campania, Southern Ital...  0.000341
# Red Blends, Red Blends, Castilla and Leon, Nort...  0.001247
# Red Blends, Red Blends, Castilla-La Mancha, Cen...  0.000688
# Red Blends, Red Blends, Catalunya, Northeast Sp...  0.001120
# Red Blends, Red Blends, Clear Lake, North Coast...  0.000867
# Red Blends, Red Blends, Coastal Region, South A...  0.000256
# Red Blends, Red Blends, Colchagua Valley, Centr...  0.001027
# Red Blends, Red Blends, Columbia Valley, Oregon... -0.000023
# Red Blends, Red Blends, Columbia Valley, Washin...  0.000136
# Red Blends, Red Blends, Coteaux de Languedoc, L... -0.000374
# Red Blends, Red Blends, Douro Valley, Portugal     -0.000100
# Red Blends, Red Blends, Galilee, Israel            -0.000421
# Red Blends, Red Blends, Inland Valleys, Califor...  0.001037
# Red Blends, Red Blends, Judea, Israel              -0.000136
# Red Blends, Red Blends, La Rioja, Northeast Spa...  0.000624
# Red Blends, Red Blends, Le Marche, Central Ital...  0.000135
# Red Blends, Red Blends, Long Island, New York, USA -0.000604
# Red Blends, Red Blends, Macedonia, Greece          -0.000173
# Red Blends, Red Blends, Maipo Valley, Central V...  0.000602
# Red Blends, Red Blends, Maule Valley, Central V...  0.001089
# Red Blends, Red Blends, Mendocino, North Coast,...  0.001161
# Red Blends, Red Blends, Mendoza, Argentina          0.000753
# Red Blends, Red Blends, Murcia, Northeast Spain...  0.000774
# Red Blends, Red Blends, Napa Valley, North Coas...  0.000363
# Red Blends, Red Blends, Navarra, Northeast Spai...  0.000587
# Red Blends, Red Blends, Niederosterreich, Austria   0.000246
# Red Blends, Red Blends, Paso Robles, Central Co... -0.000355
# Red Blends, Red Blends, Piedmont, Northwest Ita...  0.000983
# Red Blends, Red Blends, Provence, France            0.000710
# Red Blends, Red Blends, Puglia, Southern Italy,...  0.000983
# Red Blends, Red Blends, San Francisco Bay, Cent...  0.000686
# Red Blends, Red Blends, Santa Barbara, Central ... -0.000617
# Red Blends, Red Blends, Sardinia, Southern Ital...  0.000458
# Red Blends, Red Blends, Sicily, Southern Italy,...  0.000445
# Red Blends, Red Blends, Sierra Foothills, Calif...  0.000930
# Red Blends, Red Blends, Sonoma Valley, North Co...  0.000234
# Red Blends, Red Blends, South Australia, Australia  0.000081
# Red Blends, Red Blends, South Coast, California... -0.000038
# Red Blends, Red Blends, Southern Greece, Greece     0.000100
# Red Blends, Red Blends, Southern Oregon, Oregon...  0.000143
# Red Blends, Red Blends, Southwest France, France    0.000603
# Red Blends, Red Blends, Thracian Valley, Bulgaria  -0.000588
# Red Blends, Red Blends, Tuscany, Central Italy,...  0.000383
# Red Blends, Red Blends, Umbria, Central Italy, ...  0.000016
# Red Blends, Red Blends, Valencia, Northeast Spa...  0.001355
# Red Blends, Red Blends, Veneto, Northeast Italy...  0.000166
# Ribolla Gialla, Italian White, Friuli-Venezia G... -0.000892
# Riesling, Alsace, France                           -0.000508
# Riesling, Canterbury and Waipara, New Zealand      -0.000588
# Riesling, Central Otago, New Zealand               -0.000465
# Riesling, Columbia Valley, Washington, USA         -0.000714
# Riesling, Finger Lakes, New York, USA              -0.000522
# Riesling, Idaho, USA                               -0.000540
# Riesling, Long Island, New York, USA               -0.000844
# Riesling, Marlborough, New Zealand                 -0.000525
# Riesling, Mendocino, North Coast, California, USA  -0.000647
# Riesling, Michigan, USA                            -0.000447
# Riesling, Mosel, Germany                           -0.000761
# Riesling, Nahe, Germany                            -0.000301
# Riesling, Niederosterreich, Austria                -0.000445
# Riesling, Ontario, Canada                          -0.000569
# Riesling, Pfalz, Germany                           -0.000708
# Riesling, Rheingau, Germany                        -0.000649
# Riesling, Rheinhessen, Germany                     -0.000510
# Riesling, Santa Barbara, Central Coast, Califor...  0.000336
# Riesling, South Australia, Australia               -0.000279
# Riesling, Southern Oregon, Oregon, USA             -0.000442
# Riesling, Western Australia, Australia             -0.000288
# Riesling, Willamette Valley, Oregon, USA           -0.000575
# Sagrantino, Italian Red, Umbria, Central Italy,...  0.001088
# Sangiovese, Columbia Valley, Washington, USA       -0.000189
# Sangiovese, Emilia-Romagna, Northeast Italy, Italy -0.000031
# Sangiovese, Sierra Foothills, California, USA       0.001186
# Sangiovese, Tuscany, Central Italy, Italy           0.000931
# Sauvignon Blanc, Alto Adige, Northeast Italy, I... -0.000874
# Sauvignon Blanc, Burgenland, Austria               -0.000898
# Sauvignon Blanc, Cape South Coast, South Africa    -0.000425
# Sauvignon Blanc, Casablanca Valley, Aconcagua R... -0.000062
# Sauvignon Blanc, Castilla and Leon, Northwest S...  0.000060
# Sauvignon Blanc, Centre, Loire Valley, France      -0.000266
# Sauvignon Blanc, Clear Lake, North Coast, Calif... -0.000823
# Sauvignon Blanc, Coastal Region, South Africa      -0.000698
# Sauvignon Blanc, Colchagua Valley, Central Vall... -0.000184
# Sauvignon Blanc, Columbia Valley, Washington, USA  -0.000713
# Sauvignon Blanc, Curico Valley, Central Valley,...  0.000143
# Sauvignon Blanc, Finger Lakes, New York, USA       -0.000304
# Sauvignon Blanc, Friuli-Venezia Giulia, Northea... -0.000879
# Sauvignon Blanc, Hawkes Bay, New Zealand           -0.000894
# Sauvignon Blanc, Inland Valleys, California, USA   -0.001000
# Sauvignon Blanc, Long Island, New York, USA        -0.000710
# Sauvignon Blanc, Maipo Valley, Central Valley, ... -0.000346
# Sauvignon Blanc, Marlborough, New Zealand          -0.000805
# Sauvignon Blanc, Maule Valley, Central Valley, ... -0.000133
# Sauvignon Blanc, Mendocino, North Coast, Califo... -0.000921
# Sauvignon Blanc, Mendoza, Argentina                 0.000006
# Sauvignon Blanc, Monterey, Central Coast, Calif... -0.000743
# Sauvignon Blanc, Napa Valley, North Coast, Cali... -0.000336
# Sauvignon Blanc, Paso Robles, Central Coast, Ca...  0.000344
# Sauvignon Blanc, San Antonio Valley, Aconcagua,... -0.000007
# Sauvignon Blanc, San Antonio, Aconcagua Region,...  0.000129
# Sauvignon Blanc, San Luis Obispo, Central Coast... -0.000648
# Sauvignon Blanc, Santa Barbara, Central Coast, ...  0.000028
# Sauvignon Blanc, Sierra Foothills, California, USA -0.001046
# Sauvignon Blanc, Sonoma Valley, North Coast, Ca... -0.000544
# Sauvignon Blanc, South Australia, Australia        -0.000788
# Sauvignon Blanc, Southern Oregon, Oregon, USA      -0.000574
# Sauvignon Blanc, Southwest France, France          -0.001054
# Sauvignon Blanc, Steiermark, Austria               -0.000743
# Sauvignon Blanc, Touraine, Loire Valley, France    -0.000610
# Sauvignon Blanc, Wairarapa, New Zealand            -0.000843
# Sauvignon Blanc-Semillon, White Blend, Western ... -0.000626
# Shiraz-Cabernet Sauvignon, Red Blends, South Au... -0.000512
# Shiraz-Viognier, South Australia, Australia        -0.000327
# SpÃ¤tburgunder, Pinot Noir, Baden, Germany         -0.000494
# Syrah, Aconcagua Valley, Aconcagua Region, Chile    0.000086
# Syrah, Alentejo, Portugal                           0.000530
# Syrah, Cachapoal Valley, Central Valley, Chile      0.001187
# Syrah, Casablanca Valley, Aconcagua Region, Chile   0.000695
# Syrah, Coastal Region, South Africa                 0.000444
# Syrah, Colchagua Valley, Central Valley, Chile      0.000628
# Syrah, Columbia Valley, Oregon, USA                 0.000021
# Syrah, Columbia Valley, Washington, USA             0.000022
# Syrah, Galilee, Israel                             -0.000512
# Syrah, Hawkes Bay, New Zealand                      0.000013
# Syrah, Inland Valleys, California, USA              0.001016
# Syrah, Limari Valley, Coquimbo Region, Chile        0.000882
# Syrah, Maipo Valley, Central Valley, Chile          0.000427
# Syrah, Mendocino, North Coast, California, USA      0.000879
# Syrah, Mendoza, Argentina                           0.000682
# Syrah, Monterey, Central Coast, California, USA    -0.000212
# Syrah, Napa Valley, North Coast, California, USA    0.000409
# Syrah, New South Wales, Australia                   0.000303
# Syrah, Northern Rhone, Rhone Valley, France         0.000173
# Syrah, Paso Robles, Central Coast, California, USA -0.000123
# Syrah, San Francisco Bay, Central Coast, Califo... -0.000199
# Syrah, San Luis Obispo, Central Coast, Californ... -0.000442
# Syrah, Santa Barbara, Central Coast, California... -0.000198
# Syrah, Sierra Foothills, California, USA            0.000840
# Syrah, Sonoma Valley, North Coast, California, USA  0.000248
# Syrah, South Australia, Australia                  -0.000145
# Syrah, South Coast, California, USA                 0.000254
# Syrah, Southern Oregon, Oregon, USA                 0.000485
# Syrah, Tuscany, Central Italy, Italy                0.000603
# Syrah, Victoria, Australia                          0.000361
# Syrah, Western Australia, Australia                -0.000201
# Tannat-Cabernet, Red Blends, Southwest France, ...  0.000424
# Tempranillo Blend, Tempranillo, Castilla and Le...  0.001123
# Tempranillo Blend, Tempranillo, La Rioja, North...  0.000762
# Tempranillo Blend, Tempranillo, Navarra, Northe...  0.001199
# Tempranillo, Castilla and Leon, Northwest Spain...  0.001224
# Tempranillo, Castilla-La Mancha, Central Spain,...  0.000578
# Tempranillo, Columbia Valley, Washington, USA       0.000260
# Tempranillo, Inland Valleys, California, USA        0.000149
# Tempranillo, La Rioja, Northeast Spain, Spain       0.000731
# Tempranillo, Mendoza, Argentina                     0.000249
# Tempranillo, Navarra, Northeast Spain, Spain        0.000838
# Tempranillo, Sierra Foothills, California, USA      0.000791
# Tempranillo, Southern Oregon, Oregon, USA           0.000642
# Tempranillo, Valencia, Northeast Spain, Spain       0.000668
# Tinta de Toro, Tempranillo, Castilla and Leon, ...  0.001574
# Tinto Fino, Tempranillo, Castilla and Leon, Nor...  0.001207
# Tinto del Pais, Tempranillo, Castilla and Leon,...  0.001308
# Tokaji, White Blend, Tokaj, Hungary                -0.001016
# Tokay Pinot Gris, Alsace, France                   -0.000709
# Turbiana, Italian White, Lombardy, Northwest It... -0.000707
# Verdicchio, Italian White, Le Marche, Central I... -0.000917
# Vermentino, Italian White, Sardinia, Southern I... -0.001124
# Vernaccia, Italian White, Tuscany, Central Ital... -0.000859
# Viognier, Columbia Valley, Washington, USA         -0.000115
# Viognier, Mendoza, Argentina                        0.000453
# Viognier, Northern Rhone, Rhone Valley, France     -0.000938
# Viognier, Paso Robles, Central Coast, Californi...  0.000108
# Viognier, Santa Barbara, Central Coast, Califor...  0.000171
# Viognier, Sierra Foothills, California, USA        -0.000541
# Viognier, Sonoma Valley, North Coast, Californi... -0.000471
# Viognier, South Australia, Australia               -0.000903
# Viognier, Southern Oregon, Oregon, USA              0.000121
# Viognier, Virginia, USA                            -0.000687
# White Blend, Alsace, France                        -0.000748
# White Blend, Burgenland, Austria                   -0.000851
# White Blend, Castilla and Leon, Northwest Spain... -0.000410
# White Blend, Castilla-La Mancha, Central Spain,... -0.000082
# White Blend, Catalunya, Northeast Spain, Spain      0.000266
# White Blend, Coastal Region, South Africa          -0.000871
# White Blend, Columbia Valley, Washington, USA      -0.000618
# White Blend, Friuli-Venezia Giulia, Northeast I... -0.000738
# White Blend, Galicia, Northwest Spain, Spain       -0.000180
# White Blend, La Rioja, Northeast Spain, Spain      -0.000294
# White Blend, Long Island, New York, USA            -0.000545
# White Blend, Macedonia, Greece                     -0.000856
# White Blend, Mendoza, Argentina                    -0.000267
# White Blend, Niederosterreich, Austria             -0.000447
# White Blend, Pais Vasco, Northwest Spain, Spain    -0.000157
# White Blend, Sicily, Southern Italy, Italy         -0.001018
# White Blend, Sierra Foothills, California, USA     -0.000604
# White Blend, Southern Greece, Greece               -0.000909
# White Blend, Southwest France, France              -0.000629
# White Blend, Tuscany, Central Italy, Italy         -0.000983
# White Blend, Umbria, Central Italy, Italy          -0.001010
# White Blend, Veneto, Northeast Italy, Italy        -0.000891
# Zinfandel, Clear Lake, North Coast, California      0.001189
# Zinfandel, Columbia Valley, Washington, USA        -0.000441
# Zinfandel, Inland Valleys, California, USA          0.000036
# Zinfandel, Mendocino, North Coast, California, USA  0.000785
# Zinfandel, Napa Valley, North Coast, California...  0.000297
# Zinfandel, Paso Robles, Central Coast, Californ... -0.000206
# Zinfandel, San Francisco Bay, Central Coast, Ca... -0.000111
# Zinfandel, Sierra Foothills, California, USA        0.000540
# Zinfandel, Sonoma Valley, North Coast, Californ...  0.000133

# %%
all_nonaromas.shape
# Out:
# (482, 8)

# %%
# save the 50 top descriptors for each wine variety as a CSV file. We will us this later to dig deeper into our proposed wine recommendations.

aroma_descriptors_copy = aroma_descriptors.copy()
aroma_descriptors_copy.set_index('index', inplace=True)
aroma_descriptors_copy.dropna(inplace=True)

aroma_descriptors_copy = pd.DataFrame(aroma_descriptors_copy['value'].tolist(), index=aroma_descriptors_copy.index)
aroma_descriptors_copy.columns = ['descriptors', 'relative_frequency']
aroma_descriptors_copy.to_csv('wine_variety_descriptors.csv')

# %% [markdown]
# At the moment, it's hard to interpret the nonaroma scalars. To allow for greater interpretability, we will normalize the nonaroma scalars between 0 and 1.

# %%
all_nonaromas_normalized.head()
# Out:
#                                                                                                 aroma  \
# Aglianico, Italian Red, Basilicata, Southern It...  [-2.4160712, 1.4550973, 2.313358, 1.4033923, -...
# Aglianico, Italian Red, Campania, Southern Ital...  [-2.902863, 1.1431276, 2.1339328, 1.197455, -3...
# Alsace white blend, White Blend, Alsace, France     [0.6841231, 2.1716158, -1.8863819, 0.5209112, ...
# Arneis, Italian White, Piedmont, Northwest Ital...  [0.49244946, 2.1503158, -2.3368292, -0.0676211...
# Austrian Red Blend, Red Blends, Burgenland, Aus...  [-0.922079, 1.6624367, 0.6810632, 1.008292, -1...
#
#                                                       weight     sweet  \
# Aglianico, Italian Red, Basilicata, Southern It...  0.287186  0.139816
# Aglianico, Italian Red, Campania, Southern Ital...  0.352850  0.231326
# Alsace white blend, White Blend, Alsace, France     0.505598  0.098949
# Arneis, Italian White, Piedmont, Northwest Ital...  0.426231  0.378529
# Austrian Red Blend, Red Blends, Burgenland, Aus...  0.485828  0.465730
#
#                                                         acid  salt   piquant  \
# Aglianico, Italian Red, Basilicata, Southern It...  0.040443   NaN  0.497582
# Aglianico, Italian Red, Campania, Southern Ital...  0.048092   NaN  0.500500
# Alsace white blend, White Blend, Alsace, France     0.009150   NaN  0.203825
# Arneis, Italian White, Piedmont, Northwest Ital...  0.028204   NaN  0.204529
# Austrian Red Blend, Red Blends, Burgenland, Aus...  0.022934   NaN  0.358334
#
#                                                          fat    bitter
# Aglianico, Italian Red, Basilicata, Southern It...  0.375384  0.882557
# Aglianico, Italian Red, Campania, Southern Ital...  0.379839  0.702151
# Alsace white blend, White Blend, Alsace, France     0.452274  0.266448
# Arneis, Italian White, Piedmont, Northwest Ital...  0.657235  0.172178
# Austrian Red Blend, Red Blends, Burgenland, Aus...  0.390810  0.576143

# %%
aromas = all_nonaromas_normalized['aroma'].apply(pd.Series)

# %%
aromas.to_csv('../data/wine_vectors_aromas.csv')

# %%
def normalize(df, cols_to_normalize):
    for feature_name in cols_to_normalize:
        print(feature_name)
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        df[feature_name] = df[feature_name].apply(lambda x: (x- min_value)/(max_value-min_value))
#         (df[feature_name] - min_value) / (max_value - min_value)
    return df

all_nonaromas_normalized = normalize(all_nonaromas, cols_to_normalize=core_tastes[1:])
all_nonaromas_normalized.to_csv('wine_aromas_nonaromas.csv')
# Out:
# weight
# sweet
# acid
# salt
# piquant
# fat
# bitter

# %% [markdown]
# ### 3. Preparing our Food Dataset
#
# Now that we have our wine aroma vectors and the nonaroma scalars, we can turn our attention to food.
#
# We will want to generate nonaroma vectors for any type of food that we want a wine pairing with. For food, we don't have the luxury of being able to define nonaroma vs. aroma descriptors, so the approach we take will be slightly different:
#
# The aroma vector will be the full food embedding.
#
# We will define an embedding for each of our core nonaromas (sweet, acid, salt, piquant, fat and bitter), and the weight/body of the food. We will define the maximum distance between each of the nonaroma embeddings and a range of commonly appearing foods. The foods that least and most resemble each nonaroma will eventually allow us to create a normalized scale between 0 (very dissimilar) and 1 (very similar) to say how much a food reflects each nonaroma.
#
# First, let's load this list of common foods.

# %%
descriptor_mappings.keys()
# Out:
# dict_keys(['aroma', 'weight', 'sweet', 'acid', 'salt', 'piquant', 'fat', 'bitter'])

# %%
descriptor_mappings['bitter']
# Out:
#                                  level_3        level_2 level_1      type  \
# raw descriptor
# abras                           abrasive    high_tannin  tannin  nonaroma
# angular                          angular    high_tannin  tannin  nonaroma
# astring                       astringent    high_tannin  tannin  nonaroma
# auster                           austere    high_tannin  tannin  nonaroma
# beefi                              beefy    high_tannin  tannin  nonaroma
# bigbon                         big-boned    high_tannin  tannin  nonaroma
# bitter                            bitter    high_tannin  tannin  nonaroma
# bittersweet                  bittersweet    high_tannin  tannin  nonaroma
# brawni                            brawny    high_tannin  tannin  nonaroma
# bulki                              bulky    high_tannin  tannin  nonaroma
# choppi                            choppy    high_tannin  tannin  nonaroma
# classi                            classy     low_tannin  tannin  nonaroma
# compact                           closed    high_tannin  tannin  nonaroma
# closegrain_tannin   close-grained_tannin     low_tannin  tannin  nonaroma
# coars                             coarse    high_tannin  tannin  nonaroma
# alongsid_finegrain    finegrained_tannin     low_tannin  tannin  nonaroma
# finegrain             finegrained_tannin     low_tannin  tannin  nonaroma
# finegrain_tannin      finegrained_tannin     low_tannin  tannin  nonaroma
# firm                                firm    high_tannin  tannin  nonaroma
# fleet_tannin             fleeting_tannin     low_tannin  tannin  nonaroma
# fleshi                            fleshy    high_tannin  tannin  nonaroma
# grabbi                            grabby    high_tannin  tannin  nonaroma
# graini                            grainy    high_tannin  tannin  nonaroma
# graini_tannin                     grainy    high_tannin  tannin  nonaroma
# grip                            gripping    high_tannin  tannin  nonaroma
# tannic_grip              gripping_tannin    high_tannin  tannin  nonaroma
# grippi                            grippy    high_tannin  tannin  nonaroma
# grit                              gritty    high_tannin  tannin  nonaroma
# gritti                            gritty    high_tannin  tannin  nonaroma
# hard                                hard    high_tannin  tannin  nonaroma
# sizabl_tannin                high_tannin    high_tannin  tannin  nonaroma
# tannic_bite                  high_tannin    high_tannin  tannin  nonaroma
# tannic_backbon               high_tannin    high_tannin  tannin  nonaroma
# jag                               jagged    high_tannin  tannin  nonaroma
# masculin                       masculine    high_tannin  tannin  nonaroma
# meati                              meaty    high_tannin  tannin  nonaroma
# moder_tannic               medium_tannin  medium_tannin  tannin  nonaroma
# mild_bitter              mild_bitterness  medium_tannin  tannin  nonaroma
# muscular                        muscular    high_tannin  tannin  nonaroma
# phenol                          phenolic    high_tannin  tannin  nonaroma
# pillowi                          pillowy     low_tannin  tannin  nonaroma
# pleasant_bitter          pleasant_bitter  medium_tannin  tannin  nonaroma
# plush                              plush     low_tannin  tannin  nonaroma
# alongsid_polish                 polished     low_tannin  tannin  nonaroma
# polish                          polished     low_tannin  tannin  nonaroma
# powderi                          powdery     low_tannin  tannin  nonaroma
# raspi                              raspy    high_tannin  tannin  nonaroma
# rough                              rough    high_tannin  tannin  nonaroma
# rough_edg                          rough    high_tannin  tannin  nonaroma
# rustic                            rustic    high_tannin  tannin  nonaroma
# satini                            satiny     low_tannin  tannin  nonaroma
# scratchi                        scratchy     low_tannin  tannin  nonaroma
# silken                             silky     low_tannin  tannin  nonaroma
# silki                              silky     low_tannin  tannin  nonaroma
# sinewi                            sinewy    high_tannin  tannin  nonaroma
# sleek                              sleek     low_tannin  tannin  nonaroma
# smooth                            smooth     low_tannin  tannin  nonaroma
# soft                                soft     low_tannin  tannin  nonaroma
# softer                              soft     low_tannin  tannin  nonaroma
# suppl                             supple     low_tannin  tannin  nonaroma
# tannic                            tannin    high_tannin  tannin  nonaroma
# tight                              tight    high_tannin  tannin  nonaroma
# tight_knit                         tight    high_tannin  tannin  nonaroma
# tight_wound                        tight    high_tannin  tannin  nonaroma
# tighter                            tight    high_tannin  tannin  nonaroma
# alongsid_velveti                 velvety     low_tannin  tannin  nonaroma
# velvet                           velvety     low_tannin  tannin  nonaroma
# velveti                          velvety     low_tannin  tannin  nonaroma
# velveti_textur                   velvety     low_tannin  tannin  nonaroma
# velveti_tannin            velvety_tannin     low_tannin  tannin  nonaroma
#
#                    primary taste       combined
# raw descriptor
# abras                     bitter    high_tannin
# angular                   bitter    high_tannin
# astring                   bitter    high_tannin
# auster                    bitter    high_tannin
# beefi                     bitter    high_tannin
# bigbon                    bitter    high_tannin
# bitter                    bitter    high_tannin
# bittersweet               bitter    high_tannin
# brawni                    bitter    high_tannin
# bulki                     bitter    high_tannin
# choppi                    bitter    high_tannin
# classi                    bitter     low_tannin
# compact                   bitter    high_tannin
# closegrain_tannin         bitter     low_tannin
# coars                     bitter    high_tannin
# alongsid_finegrain        bitter     low_tannin
# finegrain                 bitter     low_tannin
# finegrain_tannin          bitter     low_tannin
# firm                      bitter    high_tannin
# fleet_tannin              bitter     low_tannin
# fleshi                    bitter    high_tannin
# grabbi                    bitter    high_tannin
# graini                    bitter    high_tannin
# graini_tannin             bitter    high_tannin
# grip                      bitter    high_tannin
# tannic_grip               bitter    high_tannin
# grippi                    bitter    high_tannin
# grit                      bitter    high_tannin
# gritti                    bitter    high_tannin
# hard                      bitter    high_tannin
# sizabl_tannin             bitter    high_tannin
# tannic_bite               bitter    high_tannin
# tannic_backbon            bitter    high_tannin
# jag                       bitter    high_tannin
# masculin                  bitter    high_tannin
# meati                     bitter    high_tannin
# moder_tannic              bitter  medium_tannin
# mild_bitter               bitter  medium_tannin
# muscular                  bitter    high_tannin
# phenol                    bitter    high_tannin
# pillowi                   bitter     low_tannin
# pleasant_bitter           bitter  medium_tannin
# plush                     bitter     low_tannin
# alongsid_polish           bitter     low_tannin
# polish                    bitter     low_tannin
# powderi                   bitter     low_tannin
# raspi                     bitter    high_tannin
# rough                     bitter    high_tannin
# rough_edg                 bitter    high_tannin
# rustic                    bitter    high_tannin
# satini                    bitter     low_tannin
# scratchi                  bitter     low_tannin
# silken                    bitter     low_tannin
# silki                     bitter     low_tannin
# sinewi                    bitter    high_tannin
# sleek                     bitter     low_tannin
# smooth                    bitter     low_tannin
# soft                      bitter     low_tannin
# softer                    bitter     low_tannin
# suppl                     bitter     low_tannin
# tannic                    bitter    high_tannin
# tight                     bitter    high_tannin
# tight_knit                bitter    high_tannin
# tight_wound               bitter    high_tannin
# tighter                   bitter    high_tannin
# alongsid_velveti          bitter     low_tannin
# velvet                    bitter     low_tannin
# velveti                   bitter     low_tannin
# velveti_textur            bitter     low_tannin
# velveti_tannin            bitter     low_tannin

# %%
wino_foods.loc[wino_foods['Food'].str.contains('shrimp'), "wino_food_cat"] = "shellfish"

# %%
foods = pd.read_csv('list_of_foods.csv')

# %%
foods_list = list(foods['Food'])
foods_list_normalized = [normalize_text(f) for f in foods_list]
foods_list_preprocessed = [food_trigram_model[f][0] for f in foods_list_normalized]
foods_list_preprocessed = list(set(foods_list_preprocessed))

# %%
wino_foods = pd.read_csv('../data/wino_foods.csv')

# %%
wino_foods = wino_foods[wino_foods['wino_food_cat'].isnull() ==False]

# %%
print(foods.shape)
print(wino_foods.shape)
# Out:
# (805, 1)
# (52, 2)

# %% [markdown]
# Load the word embedding for each food in the list of sample foods, and save to a dictionary.

# %%
foods_vecs = dict()

word_vectors = wine_word2vec_model.wv
for f in foods_list_preprocessed:
    try:
        food_vec = word_vectors[f]
        foods_vecs[f] = food_vec
    except:
        continue

# %% [markdown]
# Now, we can define the nonaroma embeddings + the weight embedding as the average of foods that represent each nonaroma characteristic.

# %%
foods_vecs['bacon'][:4]
# Out:
# array([ 1.5013604, -1.0607009,  2.8042848,  0.7451269], dtype=float32)

# %%
food_vec_df = pd.DataFrame(foods_vecs).T

# %%
food_vec_df = food_vec_df.reset_index().rename(columns={'index':'foods'})

# %%
food_vec_df['foods'] = food_vec_df['foods'].str.lower()

# %%
wino_foods.head(2)
# Out:
#            Food wino_food_cat
# 0  acorn squash           NaN
# 1     aguachile           NaN

# %%
wino_food_vectors = food_vec_df.merge(wino_foods, left_on=['foods'], right_on=['Food'])

# %%
#wino_food_vectors.to_csv('../data/wino_food_vectors.csv', index=False)

# %%
from scipy import spatial

core_tastes_revised = {'weight': ['heavy', 'cassoulet', 'cassoulet', 'full_bodied', 'thick', 'milk', 'fat', 'mincemeat', 'steak', 'bold', 'pizza', 'pasta', 'creamy', 'bread'],
                       'sweet': ['sweet', 'sugar', 'cake', 'mango', 'stevia'], 
                       'acid': ['acid', 'sour', 'vinegar', 'yoghurt', 'cevich', 'cevich'],
                       'salt': ['salt',  'parmesan', 'oyster', 'pizza', 'bacon', 'cured_meat', 'sausage', 'potato_chip'], 
                       'piquant': ['spicy'], 
                       'fat': ['fat', 'fried', 'creamy', 'cassoulet', 'foie_gras', 'buttery', 'cake', 'foie_gras', 'sausage', 'brie', 'carbonara'], 
                       'bitter': ['bitter', 'kale']
                      }

average_taste_vecs = dict()
core_tastes_distances = dict()
for taste, keywords in core_tastes_revised.items():
    
    all_keyword_vecs = []
    for keyword in keywords:
        c_vec = word_vectors[keyword]
        all_keyword_vecs.append(c_vec)
    
    avg_taste_vec = np.average(all_keyword_vecs, axis=0)
    average_taste_vecs[taste] = avg_taste_vec
        
    taste_distances = dict()
    for k, v in foods_vecs.items():
        similarity = 1- spatial.distance.cosine(avg_taste_vec, v)
        taste_distances[k] = similarity
        
    core_tastes_distances[taste] = taste_distances

# %% [markdown]
# We can now find out which foods most and least resemble each nonaroma.

# %%
food_nonaroma_infos = dict()
# for each core taste, identify the food item that is farthest and closest. We will need this to create a normalized scale between 0 and 1
for key, value in core_tastes_revised.items():
    dict_taste = dict()
    farthest = min(core_tastes_distances[key], key=core_tastes_distances[key].get)
    farthest_distance = core_tastes_distances[key][farthest]
    closest = max(core_tastes_distances[key], key=core_tastes_distances[key].get)
    closest_distance = core_tastes_distances[key][closest]
    print(key, farthest, closest)
    dict_taste['farthest'] = farthest_distance
    dict_taste['closest'] = closest_distance
    dict_taste['average_vec'] = average_taste_vecs[key]
    food_nonaroma_infos[key] = dict_taste
# Out:
# weight dragonfruit pizza
# sweet duck honey
# acid biscuit tart
# salt nectar bacon
# piquant sole chili
# fat pain foie_gras
# bitter biscuit kale

# %% [markdown]
# Now, let's save the average embedding for each nonaroma, as well as the minimum and maximum distance to each nonaroma embedding - we will use these to scale the nonaroma scalars that we obtain for any foods we try to pair wine with.

# %%
food_nonaroma_infos_df = pd.DataFrame(food_nonaroma_infos).T
food_nonaroma_infos_df.to_csv('average_nonaroma_vectors.csv')

# %%
food_nonaroma_infos_df
# Out:
#          farthest   closest                                        average_vec
# weight  -0.149365  0.555929  [0.6324886, -0.025728464, 0.7171549, -0.148445...
# sweet   -0.172714  0.559878  [1.0993205, 0.56118524, 0.46363392, -0.7495387...
# acid    -0.134353  0.605692  [0.023289317, 0.5380496, 0.4228985, -0.3023304...
# salt    -0.122184  0.624917  [0.77468556, 0.32773042, 0.4404572, 0.07065759...
# piquant -0.117059  0.379213  [0.11172887, 0.9126143, 0.89683694, 0.08364475...
# fat     -0.069134  0.539971  [0.25869295, -0.055616256, 0.22269298, 0.06478...
# bitter  -0.170265  0.516227  [0.68754536, 0.4415164, 0.36681026, -1.7305741...

# %% [markdown]
# We have all the pieces we need to build our wine recommendations. We will continue with this in a separate notebook.
